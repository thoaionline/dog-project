# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[8])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

humans_in_humans = sum(face_detector(f) for f in human_files_short)
print('Percentage of detected human faces in first 100 human_files %s'% humans_in_humans)
humans_in_dogs = sum(face_detector(f) for f in dog_files_short)
print("Percentage of detected human faces in first 100 dog_files %s"% humans_in_dogs)
# Out:
# Percentage of detected human faces in first 100 human_files 99
# Percentage of detected human faces in first 100 dog_files 11

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# No it is not a reasonable expectation because some human-containing photos may come without a clear face. For example, people wearing eye glasses or masks, photos of people's back (without face). A better approach would be to use machine learning to "generalise" from a large data set of human photos and identify such attributes. Of course, even this approach is still limited by the training dataset. However, thanks to the evolving nature of machine learning, new data, once marked, can be added to the training set and help with future "human detection".
#
# ----
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.
dog_detector_in_dog_files = sum(dog_detector(p) for p in dog_files_short)
print('Percentage of dogs detected in dog files %s'%dog_detector_in_dog_files);
dog_detector_in_human_files = sum(dog_detector(p) for p in human_files_short)
print('Percentage of dogs detected in human files %s'%dog_detector_in_human_files);
# Out:
# Percentage of dogs detected in dog files 100
# Percentage of dogs detected in human files 2

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [00:35<00:00, 186.06it/s]
# 100%|██████████| 835/835 [00:04<00:00, 206.18it/s]
# 100%|██████████| 836/836 [00:04<00:00, 206.90it/s]

# %%
train_tensors.shape
# Out:
# (6680, 224, 224, 3)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
#
# The CNN here is constructed following the example from the video lectures. At each step, the size of filters are reduced and new filters are added. A couple of dropout layers were added at the end to reduce over-fitting.

# %%
train_tensors.shape
# Out:
# (6680, 224, 224, 3)

# %%
train_targets.shape
# Out:
# (6680, 133)

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

# TODO: Define your architecture.
model.add(Conv2D(filters=16,kernel_size=2,
                 padding='same',activation='relu',
                 input_shape=(224,224,3)
                ))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=32,kernel_size=4,
                 padding='same',activation='relu'
                ))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=128,kernel_size=2,
                padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=256,kernel_size=2,
                padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters=512,kernel_size=2,
                padding='same',activation='relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(GlobalAveragePooling2D())

model.add(Dropout(0.3))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(133,activation='softmax'))

# Preview
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      8224
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 128)       16512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 256)       131328
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 256)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 512)       524800
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 1,011,957.0
# Trainable params: 1,011,957.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100 # Last time I tried, no improvement after 40th epoch (with a 100 epochs run)

# This line in only applicable for subsequent runs
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8172 - acc: 0.4889Epoch 00000: val_loss improved from inf to 3.49769, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 12s - loss: 1.8170 - acc: 0.4889 - val_loss: 3.4977 - val_acc: 0.2731
# Epoch 2/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6845 - acc: 0.5155Epoch 00001: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.6825 - acc: 0.5162 - val_loss: 3.7323 - val_acc: 0.2743
# Epoch 3/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6709 - acc: 0.5281Epoch 00002: val_loss improved from 3.49769 to 3.31819, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 12s - loss: 1.6696 - acc: 0.5286 - val_loss: 3.3182 - val_acc: 0.2683
# Epoch 4/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5988 - acc: 0.5387Epoch 00003: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.5973 - acc: 0.5392 - val_loss: 3.7005 - val_acc: 0.2611
# Epoch 5/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5481 - acc: 0.5508Epoch 00004: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.5480 - acc: 0.5513 - val_loss: 3.5277 - val_acc: 0.2599
# Epoch 6/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5311 - acc: 0.5568Epoch 00005: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.5319 - acc: 0.5566 - val_loss: 4.0404 - val_acc: 0.2228
# Epoch 7/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5361 - acc: 0.5580Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.5360 - acc: 0.5579 - val_loss: 3.5744 - val_acc: 0.2731
# Epoch 8/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4348 - acc: 0.5871Epoch 00007: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.4370 - acc: 0.5868 - val_loss: 3.9776 - val_acc: 0.2467
# Epoch 9/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4150 - acc: 0.5836Epoch 00008: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4143 - acc: 0.5843 - val_loss: 3.5474 - val_acc: 0.2419
# Epoch 10/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3946 - acc: 0.5994Epoch 00009: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4008 - acc: 0.5988 - val_loss: 3.9577 - val_acc: 0.2036
# Epoch 11/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3850 - acc: 0.6072Epoch 00010: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.3844 - acc: 0.6069 - val_loss: 3.9774 - val_acc: 0.2359
# Epoch 12/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3577 - acc: 0.6035Epoch 00011: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3574 - acc: 0.6033 - val_loss: 4.1520 - val_acc: 0.2491
# Epoch 13/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3449 - acc: 0.6114Epoch 00012: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3453 - acc: 0.6112 - val_loss: 3.8118 - val_acc: 0.2731
# Epoch 14/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3687 - acc: 0.6090Epoch 00013: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3694 - acc: 0.6090 - val_loss: 3.7463 - val_acc: 0.2563
# Epoch 15/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3262 - acc: 0.6141Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3247 - acc: 0.6144 - val_loss: 4.3371 - val_acc: 0.2898
# Epoch 16/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3130 - acc: 0.6114Epoch 00015: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3133 - acc: 0.6114 - val_loss: 3.8750 - val_acc: 0.2563
# Epoch 17/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3450 - acc: 0.6168Epoch 00016: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.3444 - acc: 0.6169 - val_loss: 3.8599 - val_acc: 0.2707
# Epoch 18/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3335 - acc: 0.6203Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3335 - acc: 0.6205 - val_loss: 4.2420 - val_acc: 0.2910
# Epoch 19/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.3372 - acc: 0.6129Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.3377 - acc: 0.6127 - val_loss: 3.9968 - val_acc: 0.2515
# Epoch 20/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4310 - acc: 0.6027Epoch 00019: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4294 - acc: 0.6028 - val_loss: 3.8907 - val_acc: 0.2515
# Epoch 21/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4328 - acc: 0.6069Epoch 00020: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.4320 - acc: 0.6070 - val_loss: 5.9265 - val_acc: 0.2323
# Epoch 22/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4012 - acc: 0.6146Epoch 00021: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4029 - acc: 0.6141 - val_loss: 4.9067 - val_acc: 0.2108
# Epoch 23/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4606 - acc: 0.5944Epoch 00022: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4584 - acc: 0.5951 - val_loss: 3.8429 - val_acc: 0.2958
# Epoch 24/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4503 - acc: 0.6036Epoch 00023: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.4540 - acc: 0.6027 - val_loss: 4.1119 - val_acc: 0.2072
# Epoch 25/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4920 - acc: 0.5980Epoch 00024: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4968 - acc: 0.5973 - val_loss: 3.8081 - val_acc: 0.2000
# Epoch 26/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4497 - acc: 0.6074Epoch 00025: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4475 - acc: 0.6079 - val_loss: 4.3584 - val_acc: 0.2635
# Epoch 27/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4604 - acc: 0.6071Epoch 00026: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4635 - acc: 0.6069 - val_loss: 3.8742 - val_acc: 0.2323
# Epoch 28/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 1.4405 - acc: 0.6068Epoch 00027: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4408 - acc: 0.6067 - val_loss: 5.1201 - val_acc: 0.2036
# Epoch 29/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4498 - acc: 0.6032Epoch 00028: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.4494 - acc: 0.6033 - val_loss: 4.2083 - val_acc: 0.2515
# Epoch 30/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4689 - acc: 0.6065Epoch 00029: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.4684 - acc: 0.6064 - val_loss: 4.2149 - val_acc: 0.2838
# Epoch 31/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4542 - acc: 0.6075Epoch 00030: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4526 - acc: 0.6072 - val_loss: 5.2960 - val_acc: 0.2515
# Epoch 32/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4934 - acc: 0.6026Epoch 00031: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4969 - acc: 0.6016 - val_loss: 4.7739 - val_acc: 0.1868
# Epoch 33/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5028 - acc: 0.5977Epoch 00032: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.5024 - acc: 0.5975 - val_loss: 4.4276 - val_acc: 0.2551
# Epoch 34/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5561 - acc: 0.6065Epoch 00033: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.5567 - acc: 0.6061 - val_loss: 4.1364 - val_acc: 0.2539
# Epoch 35/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.4926 - acc: 0.6092Epoch 00034: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.4918 - acc: 0.6091 - val_loss: 4.5885 - val_acc: 0.2707
# Epoch 36/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.5604 - acc: 0.5896Epoch 00035: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.5596 - acc: 0.5898 - val_loss: 4.0156 - val_acc: 0.2790
# Epoch 37/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6088 - acc: 0.5896Epoch 00036: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.6100 - acc: 0.5897 - val_loss: 3.7386 - val_acc: 0.2455
# Epoch 38/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.6394 - acc: 0.5749Epoch 00037: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.6384 - acc: 0.5751 - val_loss: 3.8841 - val_acc: 0.2683
# Epoch 39/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7422 - acc: 0.5607Epoch 00038: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.7425 - acc: 0.5603 - val_loss: 3.4148 - val_acc: 0.2743
# Epoch 40/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.7624 - acc: 0.5556Epoch 00039: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.7653 - acc: 0.5551 - val_loss: 4.4278 - val_acc: 0.1796
# Epoch 41/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8918 - acc: 0.5420Epoch 00040: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.8914 - acc: 0.5424 - val_loss: 6.0874 - val_acc: 0.1784
# Epoch 42/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8867 - acc: 0.5341Epoch 00041: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.8870 - acc: 0.5340 - val_loss: 3.8926 - val_acc: 0.2311
# Epoch 43/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.8964 - acc: 0.5263Epoch 00042: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 1.9021 - acc: 0.5259 - val_loss: 3.6460 - val_acc: 0.2240
# Epoch 44/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 1.9915 - acc: 0.5260Epoch 00043: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.9904 - acc: 0.5262 - val_loss: 5.0408 - val_acc: 0.2443
# Epoch 45/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0671 - acc: 0.5105Epoch 00044: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.0655 - acc: 0.5109 - val_loss: 3.5988 - val_acc: 0.2790
# Epoch 46/100
# 6640/6680 [============================>.] - ETA: 0s - loss: 1.9429 - acc: 0.5267Epoch 00045: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 1.9412 - acc: 0.5268 - val_loss: 4.1395 - val_acc: 0.2204
# Epoch 47/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0164 - acc: 0.5086Epoch 00046: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.0150 - acc: 0.5090 - val_loss: 4.1734 - val_acc: 0.2539
# Epoch 48/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1826 - acc: 0.4881Epoch 00047: val_loss improved from 3.31819 to 3.26875, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 13s - loss: 2.1809 - acc: 0.4886 - val_loss: 3.2688 - val_acc: 0.2407
# Epoch 49/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0828 - acc: 0.4947Epoch 00048: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.0845 - acc: 0.4942 - val_loss: 4.5601 - val_acc: 0.2036
# Epoch 50/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1884 - acc: 0.4899Epoch 00049: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.1869 - acc: 0.4906 - val_loss: 3.9673 - val_acc: 0.2192
# Epoch 51/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2929 - acc: 0.4751Epoch 00050: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.2906 - acc: 0.4753 - val_loss: 3.6202 - val_acc: 0.2228
# Epoch 52/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1382 - acc: 0.4932Epoch 00051: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.1369 - acc: 0.4934 - val_loss: 4.4488 - val_acc: 0.2347
# Epoch 53/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2062 - acc: 0.4865Epoch 00052: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.2096 - acc: 0.4862 - val_loss: 3.4267 - val_acc: 0.1928
# Epoch 54/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1224 - acc: 0.4857Epoch 00053: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.1215 - acc: 0.4861 - val_loss: 4.2330 - val_acc: 0.2204
# Epoch 55/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.0454 - acc: 0.5051Epoch 00054: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.0447 - acc: 0.5054 - val_loss: 6.0722 - val_acc: 0.1737
# Epoch 56/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.1679 - acc: 0.4811Epoch 00055: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.1647 - acc: 0.4816 - val_loss: 3.9549 - val_acc: 0.2635
# Epoch 57/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2031 - acc: 0.4829Epoch 00056: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.2019 - acc: 0.4828 - val_loss: 3.5412 - val_acc: 0.2539
# Epoch 58/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3012 - acc: 0.4632Epoch 00057: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.3020 - acc: 0.4633 - val_loss: 4.8805 - val_acc: 0.1964
# Epoch 59/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.2322 - acc: 0.4679Epoch 00058: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.2342 - acc: 0.4677 - val_loss: 3.8433 - val_acc: 0.2407
# Epoch 60/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3790 - acc: 0.4447Epoch 00059: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.3794 - acc: 0.4440 - val_loss: 6.3058 - val_acc: 0.1389
# Epoch 61/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4308 - acc: 0.4357Epoch 00060: val_loss improved from 3.26875 to 3.26388, saving model to saved_models/weights.best.from_scratch.hdf5
# 6680/6680 [==============================] - 13s - loss: 2.4296 - acc: 0.4358 - val_loss: 3.2639 - val_acc: 0.2347
# Epoch 62/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.4750 - acc: 0.4290Epoch 00061: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.4745 - acc: 0.4290 - val_loss: 4.6543 - val_acc: 0.2048
# Epoch 63/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.3875 - acc: 0.4371Epoch 00062: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.3894 - acc: 0.4371 - val_loss: 5.4032 - val_acc: 0.1868
# Epoch 64/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5295 - acc: 0.4243Epoch 00063: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.5251 - acc: 0.4250 - val_loss: 4.9344 - val_acc: 0.2443
# Epoch 65/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.6092 - acc: 0.4227Epoch 00064: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.6065 - acc: 0.4231 - val_loss: 3.9886 - val_acc: 0.2479
# Epoch 66/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5436 - acc: 0.4174Epoch 00065: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.5413 - acc: 0.4177 - val_loss: 3.3937 - val_acc: 0.2635
# Epoch 67/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5650 - acc: 0.4156Epoch 00066: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.5632 - acc: 0.4157 - val_loss: 3.6651 - val_acc: 0.2731
# Epoch 68/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5869 - acc: 0.4200Epoch 00067: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.5841 - acc: 0.4202 - val_loss: 3.8467 - val_acc: 0.2443
# Epoch 69/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5244 - acc: 0.4161Epoch 00068: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.5255 - acc: 0.4162 - val_loss: 3.7373 - val_acc: 0.1737
# Epoch 70/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5124 - acc: 0.4254Epoch 00069: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.5112 - acc: 0.4254 - val_loss: 3.7572 - val_acc: 0.2323
# Epoch 71/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5115 - acc: 0.4096Epoch 00070: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.5124 - acc: 0.4094 - val_loss: 6.0161 - val_acc: 0.1581
# Epoch 72/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7123 - acc: 0.4054Epoch 00071: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.7093 - acc: 0.4058 - val_loss: 4.4554 - val_acc: 0.1928
# Epoch 73/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5808 - acc: 0.4074Epoch 00072: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.5842 - acc: 0.4066 - val_loss: 3.8178 - val_acc: 0.1581
# Epoch 74/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.6282 - acc: 0.4017Epoch 00073: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.6265 - acc: 0.4018 - val_loss: 3.3730 - val_acc: 0.2515
# Epoch 75/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.5407 - acc: 0.4096Epoch 00074: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.5398 - acc: 0.4102 - val_loss: 3.4361 - val_acc: 0.2383
# Epoch 76/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8052 - acc: 0.3899Epoch 00075: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.8062 - acc: 0.3894 - val_loss: 3.2673 - val_acc: 0.2443
# Epoch 77/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7928 - acc: 0.3740Epoch 00076: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.7954 - acc: 0.3735 - val_loss: 4.4056 - val_acc: 0.1916
# Epoch 78/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7586 - acc: 0.3739Epoch 00077: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.7606 - acc: 0.3735 - val_loss: 3.6956 - val_acc: 0.2096
# Epoch 79/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7641 - acc: 0.3866Epoch 00078: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.7629 - acc: 0.3867 - val_loss: 3.8914 - val_acc: 0.2263
# Epoch 80/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9073 - acc: 0.3701Epoch 00079: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9056 - acc: 0.3701 - val_loss: 3.7079 - val_acc: 0.2407
# Epoch 81/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9038 - acc: 0.3641Epoch 00080: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9018 - acc: 0.3636 - val_loss: 3.6156 - val_acc: 0.2000
# Epoch 82/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9254 - acc: 0.3608Epoch 00081: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9263 - acc: 0.3606 - val_loss: 5.2074 - val_acc: 0.1665
# Epoch 83/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8679 - acc: 0.3616Epoch 00082: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.8681 - acc: 0.3612 - val_loss: 3.7826 - val_acc: 0.2395
# Epoch 84/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9331 - acc: 0.3523Epoch 00083: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.9356 - acc: 0.3518 - val_loss: 3.4191 - val_acc: 0.2144
# Epoch 85/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8410 - acc: 0.3763Epoch 00084: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.8435 - acc: 0.3759 - val_loss: 3.4737 - val_acc: 0.1665
# Epoch 86/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9385 - acc: 0.3482Epoch 00085: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.9355 - acc: 0.3493 - val_loss: 4.7730 - val_acc: 0.1832
# Epoch 87/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.7275 - acc: 0.3811Epoch 00086: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.7228 - acc: 0.3817 - val_loss: 3.8073 - val_acc: 0.2635
# Epoch 88/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8837 - acc: 0.3544Epoch 00087: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.8910 - acc: 0.3540 - val_loss: 7.1881 - val_acc: 0.0898
# Epoch 89/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8881 - acc: 0.3596Epoch 00088: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.8902 - acc: 0.3591 - val_loss: 3.6173 - val_acc: 0.1581
# Epoch 90/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9057 - acc: 0.3646Epoch 00089: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9033 - acc: 0.3647 - val_loss: 3.4048 - val_acc: 0.2108
# Epoch 91/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9973 - acc: 0.3547Epoch 00090: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9949 - acc: 0.3545 - val_loss: 3.8901 - val_acc: 0.2419
# Epoch 92/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8492 - acc: 0.3577Epoch 00091: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.8489 - acc: 0.3578 - val_loss: 3.6862 - val_acc: 0.2311
# Epoch 93/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0195 - acc: 0.3434Epoch 00092: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 3.0196 - acc: 0.3431 - val_loss: 3.4994 - val_acc: 0.1928
# Epoch 94/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0789 - acc: 0.3333Epoch 00093: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 3.0773 - acc: 0.3334 - val_loss: 3.9810 - val_acc: 0.1844
# Epoch 95/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0320 - acc: 0.3296Epoch 00094: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 3.0312 - acc: 0.3304 - val_loss: 3.4978 - val_acc: 0.2060
# Epoch 96/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0483 - acc: 0.3345Epoch 00095: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 3.0490 - acc: 0.3340 - val_loss: 3.5785 - val_acc: 0.1868
# Epoch 97/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.0475 - acc: 0.3260Epoch 00096: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 3.0451 - acc: 0.3262 - val_loss: 4.1679 - val_acc: 0.2551
# Epoch 98/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.9501 - acc: 0.3318Epoch 00097: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 2.9525 - acc: 0.3317 - val_loss: 6.1327 - val_acc: 0.1198
# Epoch 99/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 3.1169 - acc: 0.3279Epoch 00098: val_loss did not improve
# 6680/6680 [==============================] - 13s - loss: 3.1297 - acc: 0.3277 - val_loss: 3.9624 - val_acc: 0.2168
# Epoch 100/100
# 6660/6680 [============================>.] - ETA: 0s - loss: 2.8925 - acc: 0.3378Epoch 00099: val_loss did not improve
# 6680/6680 [==============================] - 12s - loss: 2.8955 - acc: 0.3379 - val_loss: 4.9340 - val_acc: 0.1641

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 25.2392%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %%
train_VGG16.shape[1:]
# Out:
# (7, 7, 512)

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229.0
# Trainable params: 68,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6280/6680 [===========================>..] - ETA: 0s - loss: 12.8222 - acc: 0.1111Epoch 00000: val_loss improved from inf to 11.40862, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 12.7890 - acc: 0.1135 - val_loss: 11.4086 - val_acc: 0.2048
# Epoch 2/20
# 6320/6680 [===========================>..] - ETA: 0s - loss: 10.8742 - acc: 0.2524Epoch 00001: val_loss improved from 11.40862 to 10.79140, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 10.8667 - acc: 0.2522 - val_loss: 10.7914 - val_acc: 0.2431
# Epoch 3/20
# 6640/6680 [============================>.] - ETA: 0s - loss: 10.3034 - acc: 0.3083Epoch 00002: val_loss improved from 10.79140 to 10.37473, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 10.3083 - acc: 0.3081 - val_loss: 10.3747 - val_acc: 0.2778
# Epoch 4/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 9.9752 - acc: 0.3437 Epoch 00003: val_loss improved from 10.37473 to 10.23946, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.9997 - acc: 0.3424 - val_loss: 10.2395 - val_acc: 0.2910
# Epoch 5/20
# 6240/6680 [===========================>..] - ETA: 0s - loss: 9.7183 - acc: 0.3631Epoch 00004: val_loss improved from 10.23946 to 10.18940, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.7374 - acc: 0.3621 - val_loss: 10.1894 - val_acc: 0.2934
# Epoch 6/20
# 6220/6680 [==========================>...] - ETA: 0s - loss: 9.5718 - acc: 0.3807Epoch 00005: val_loss improved from 10.18940 to 9.91304, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.5225 - acc: 0.3841 - val_loss: 9.9130 - val_acc: 0.3257
# Epoch 7/20
# 6660/6680 [============================>.] - ETA: 0s - loss: 9.4019 - acc: 0.3989Epoch 00006: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 9.4011 - acc: 0.3990 - val_loss: 9.9402 - val_acc: 0.3257
# Epoch 8/20
# 6580/6680 [============================>.] - ETA: 0s - loss: 9.3653 - acc: 0.4056Epoch 00007: val_loss improved from 9.91304 to 9.88535, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.3687 - acc: 0.4052 - val_loss: 9.8853 - val_acc: 0.3305
# Epoch 9/20
# 6400/6680 [===========================>..] - ETA: 0s - loss: 9.1899 - acc: 0.4095Epoch 00008: val_loss improved from 9.88535 to 9.72518, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.2217 - acc: 0.4073 - val_loss: 9.7252 - val_acc: 0.3449
# Epoch 10/20
# 6260/6680 [===========================>..] - ETA: 0s - loss: 9.1087 - acc: 0.4169Epoch 00009: val_loss improved from 9.72518 to 9.62364, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 9.0576 - acc: 0.4198 - val_loss: 9.6236 - val_acc: 0.3389
# Epoch 11/20
# 6400/6680 [===========================>..] - ETA: 0s - loss: 8.9249 - acc: 0.4292Epoch 00010: val_loss improved from 9.62364 to 9.52132, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 1s - loss: 8.9393 - acc: 0.4283 - val_loss: 9.5213 - val_acc: 0.3593
# Epoch 12/20
# 6620/6680 [============================>.] - ETA: 0s - loss: 8.7907 - acc: 0.4415Epoch 00011: val_loss improved from 9.52132 to 9.46064, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.7938 - acc: 0.4415 - val_loss: 9.4606 - val_acc: 0.3629
# Epoch 13/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.7454 - acc: 0.4482Epoch 00012: val_loss improved from 9.46064 to 9.39003, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.7604 - acc: 0.4475 - val_loss: 9.3900 - val_acc: 0.3641
# Epoch 14/20
# 6380/6680 [===========================>..] - ETA: 0s - loss: 8.6842 - acc: 0.4525Epoch 00013: val_loss improved from 9.39003 to 9.24250, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.6797 - acc: 0.4527 - val_loss: 9.2425 - val_acc: 0.3677
# Epoch 15/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.6130 - acc: 0.4596Epoch 00014: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 8.6311 - acc: 0.4584 - val_loss: 9.3013 - val_acc: 0.3641
# Epoch 16/20
# 6460/6680 [============================>.] - ETA: 0s - loss: 8.5851 - acc: 0.4605Epoch 00015: val_loss improved from 9.24250 to 9.21330, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.5935 - acc: 0.4600 - val_loss: 9.2133 - val_acc: 0.3581
# Epoch 17/20
# 6520/6680 [============================>.] - ETA: 0s - loss: 8.3886 - acc: 0.4715Epoch 00016: val_loss improved from 9.21330 to 9.09432, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.4009 - acc: 0.4707 - val_loss: 9.0943 - val_acc: 0.3844
# Epoch 18/20
# 6480/6680 [============================>.] - ETA: 0s - loss: 8.3296 - acc: 0.4778Epoch 00017: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 8.3477 - acc: 0.4766 - val_loss: 9.2188 - val_acc: 0.3689
# Epoch 19/20
# 6420/6680 [===========================>..] - ETA: 0s - loss: 8.3270 - acc: 0.4776Epoch 00018: val_loss did not improve
# 6680/6680 [==============================] - 0s - loss: 8.3075 - acc: 0.4787 - val_loss: 9.1212 - val_acc: 0.3749
# Epoch 20/20
# 6260/6680 [===========================>..] - ETA: 0s - loss: 8.3094 - acc: 0.4808Epoch 00019: val_loss improved from 9.09432 to 9.04051, saving model to saved_models/weights.best.VGG16.hdf5
# 6680/6680 [==============================] - 0s - loss: 8.2834 - acc: 0.4823 - val_loss: 9.0405 - val_acc: 0.3832

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 40.4306%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

VGG16_predict_breed('dogImages/valid/007.American_foxhound/American_foxhound_00523.jpg')
# Out:
# 'American_foxhound'

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
networks = ['InceptionV3','Resnet50','VGG16','VGG19','Xception']
bottleneck_x = {}
train_x = {}
valid_x = {}
test_x = {}

for network in networks:
    bottleneck_x[network] = np.load(
        'bottleneck_features/Dog%sData.npz'%network
    )
    train_x[network] = bottleneck_x[network]['train']
    valid_x[network] = bottleneck_x[network]['valid']
    test_x[network] = bottleneck_x[network]['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__
#
# This CNN was constructed using transfer learning from 5 different existing models without their classification layer, iteratively trained using 2 more pairs of Dropout-Dense layers. The best network is picked out among the 5 networks above.
#
# I think this is a suitable approach for the problem because:
#
# * The "base" network have very high classification accuracy, indicating that their "feature" layers are already well trained.
# * Training time is reduced significantly thanks to transfer leraning.
# * Dense and dropout layers were added to enhance classification.

# %%
### TODO: Define your architecture.
from keras.layers import Conv2D,MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Dropout,Flatten,Dense
from keras.models import Sequential

models = {}

for network in networks:
    models[network] = Sequential()
    input_shape = train_x[network].shape[1:]
    print('Input shape for ',network,': ',input_shape)
    models[network].add(
        GlobalAveragePooling2D(input_shape=input_shape)
    )
    models[network].add(Dropout(0.4))
    models[network].add(Dense(input_shape[2]))
    models[network].add(Dropout(0.4))
    models[network].add(Dense(133,activation='softmax'))
    models[network].summary()
# Out:
# Input shape for  InceptionV3 :  (5, 5, 2048)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 4,468,869.0
# Trainable params: 4,468,869.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Input shape for  Resnet50 :  (1, 1, 2048)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2048)              4196352
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 4,468,869.0
# Trainable params: 4,468,869.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Input shape for  VGG16 :  (7, 7, 512)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 330,885.0
# Trainable params: 330,885.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Input shape for  VGG19 :  (7, 7, 512)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_6 ( (None, 512)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 133)               68229
# =================================================================
# Total params: 330,885.0
# Trainable params: 330,885.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Input shape for  Xception :  (7, 7, 2048)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_7 ( (None, 2048)              0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 2048)              4196352
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 133)               272517
# =================================================================
# Total params: 4,468,869.0
# Trainable params: 4,468,869.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
for network in networks:
    models[network].compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint

checkpointers = {}

for network in networks:
    checkpointers[network] = ModelCheckpoint(
        filepath='saved_models/weights.%s.hdf5'%network, 
        verbose=1, save_best_only=True
    )

# %%
# Number of epochs to train
epochs_x = 10
loops = 15

while loops:
    for network in networks:
        print('Training the model for',network,'with',epochs_x,'epochs.')
        models[network].fit(
            train_x[network],train_targets,
            validation_data=(valid_x[network],valid_targets),
            epochs = epochs_x, batch_size=80, callbacks=[checkpointers[network]],
            verbose=0
        )

    print('\nFinish a batch. Here is the result')
    for network in networks:
        models[network].load_weights('saved_models/weights.%s.hdf5'%network)
        network_predictions = [np.argmax(models[network].predict(np.expand_dims(tensor, axis=0))) for tensor in valid_x[network]]
        accuracy = 100*np.sum(np.array(network_predictions)==np.argmax(valid_targets, axis=1))/len(network_predictions)
        print('Validation accuracy for %14s: %.4f%%' % (network,accuracy))

    print('\n---------------------------------------------------------\n')
    loops -= 1
# Out:
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss improved from inf to 4.86274, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00001: val_loss improved from 4.86274 to 3.09304, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00002: val_loss improved from 3.09304 to 2.84224, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00003: val_loss improved from 2.84224 to 2.74039, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 2.74039 to 2.56910, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss improved from inf to 3.58984, saving model to saved_models/weights.Resnet50.hdf5
# Epoch 00001: val_loss improved from 3.58984 to 2.34475, saving model to saved_models/weights.Resnet50.hdf5
# Epoch 00002: val_loss improved from 2.34475 to 1.98276, saving model to saved_models/weights.Resnet50.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss improved from inf to 15.30092, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00001: val_loss improved from 15.30092 to 13.41577, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00002: val_loss improved from 13.41577 to 12.78101, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00003: val_loss improved from 12.78101 to 12.52974, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00004: val_loss improved from 12.52974 to 12.16420, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00005: val_loss improved from 12.16420 to 11.73045, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00006: val_loss improved from 11.73045 to 11.50571, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00007: val_loss improved from 11.50571 to 11.48082, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss improved from 11.48082 to 11.21818, saving model to saved_models/weights.VGG16.hdf5
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss improved from inf to 13.54326, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00001: val_loss improved from 13.54326 to 13.02006, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00002: val_loss improved from 13.02006 to 12.53440, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00003: val_loss improved from 12.53440 to 12.02279, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00004: val_loss improved from 12.02279 to 11.20902, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00005: val_loss improved from 11.20902 to 11.08051, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00006: val_loss improved from 11.08051 to 10.64146, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00007: val_loss improved from 10.64146 to 10.46638, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00008: val_loss improved from 10.46638 to 10.46076, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss improved from inf to 1.30712, saving model to saved_models/weights.Xception.hdf5
# Epoch 00001: val_loss improved from 1.30712 to 1.01307, saving model to saved_models/weights.Xception.hdf5
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 76.6467%
# Validation accuracy for       Resnet50: 68.8623%
# Validation accuracy for          VGG16: 28.8623%
# Validation accuracy for          VGG19: 32.4551%
# Validation accuracy for       Xception: 75.4491%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 2.56910 to 2.47440, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 1.98276 to 1.83284, saving model to saved_models/weights.Resnet50.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss improved from 11.21818 to 10.87724, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss improved from 10.87724 to 10.74833, saving model to saved_models/weights.VGG16.hdf5
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss improved from 10.46076 to 10.25167, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 10.25167 to 10.16548, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00003: val_loss improved from 10.16548 to 10.12431, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 10.12431 to 10.07007, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss improved from 1.01307 to 0.82631, saving model to saved_models/weights.Xception.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 75.5689%
# Validation accuracy for          VGG16: 31.9760%
# Validation accuracy for          VGG19: 35.2096%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss improved from 10.74833 to 10.74558, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00002: val_loss improved from 10.74558 to 10.64746, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00003: val_loss improved from 10.64746 to 10.60752, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00004: val_loss improved from 10.60752 to 10.58550, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00005: val_loss improved from 10.58550 to 10.43365, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 10.07007 to 10.05177, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 75.5689%
# Validation accuracy for          VGG16: 34.3713%
# Validation accuracy for          VGG19: 36.2874%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss improved from 1.83284 to 1.76632, saving model to saved_models/weights.Resnet50.hdf5
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 10.43365 to 10.40924, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss improved from 10.05177 to 10.03937, saving model to saved_models/weights.VGG19.hdf5
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 34.4910%
# Validation accuracy for          VGG19: 35.6886%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 10.40924 to 10.37221, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 10.03937 to 10.00073, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss improved from 10.00073 to 9.98845, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss improved from 9.98845 to 9.89858, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00009: val_loss improved from 9.89858 to 9.72522, saving model to saved_models/weights.VGG19.hdf5
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 34.8503%
# Validation accuracy for          VGG19: 38.2036%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss improved from 10.37221 to 10.34375, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.3293%
# Validation accuracy for          VGG19: 38.2036%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss improved from 9.72522 to 9.65736, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.1617%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.3293%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss improved from 2.47440 to 2.39319, saving model to saved_models/weights.InceptionV3.hdf5
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.3293%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.3293%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss improved from 10.34375 to 10.33753, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.2096%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss improved from 10.33753 to 10.33224, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 34.8503%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss improved from 10.33224 to 10.32934, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 34.6108%
# Validation accuracy for          VGG19: 38.9222%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss improved from 9.65736 to 9.59870, saving model to saved_models/weights.VGG19.hdf5
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 34.6108%
# Validation accuracy for          VGG19: 39.1617%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss improved from 10.32934 to 10.30358, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.8084%
# Validation accuracy for          VGG19: 39.1617%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------
#
# Training the model for InceptionV3 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Resnet50 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG16 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss improved from 10.30358 to 10.28136, saving model to saved_models/weights.VGG16.hdf5
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for VGG19 with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
# Training the model for Xception with 10 epochs.
# Epoch 00000: val_loss did not improve
# Epoch 00001: val_loss did not improve
# Epoch 00002: val_loss did not improve
# Epoch 00003: val_loss did not improve
# Epoch 00004: val_loss did not improve
# Epoch 00005: val_loss did not improve
# Epoch 00006: val_loss did not improve
# Epoch 00007: val_loss did not improve
# Epoch 00008: val_loss did not improve
# Epoch 00009: val_loss did not improve
#
# Finish a batch. Here is the result
# Validation accuracy for    InceptionV3: 79.8802%
# Validation accuracy for       Resnet50: 74.2515%
# Validation accuracy for          VGG16: 35.6886%
# Validation accuracy for          VGG19: 39.1617%
# Validation accuracy for       Xception: 81.5569%
#
# ---------------------------------------------------------

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
best_network = 'Xception'
best_model = models[best_network]
best_model.load_weights('saved_models/weights.%s.hdf5'%best_network)

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
network_predictions = [np.argmax(best_model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_x[best_network]]
accuracy = 100*np.sum(np.array(network_predictions)==np.argmax(test_targets, axis=1))/len(network_predictions)
print('Test accuracy for %14s: %.4f%%' % (network,accuracy))
# Out:
# Test accuracy for       Xception: 79.6651%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.
from extract_bottleneck_features import extract_Xception

def predict_breed(img_path):
    bottleneck_feature = extract_Xception(path_to_tensor(img_path))
    predicted_vector = best_model.predict(bottleneck_feature)
    return dog_names[np.argmax(predicted_vector)]

print(predict_breed('dogImages/test/022.Belgian_tervuren/Belgian_tervuren_01607.jpg'))
print(predict_breed('dogImages/valid/024.Bichon_frise/Bichon_frise_01734.jpg'))
# Out:
# Belgian_tervuren
# Bichon_frise

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

def img_to_facts(img_path):
    if dog_detector(img_path):
        return ('dog',predict_breed(img_path))
    
    if face_detector(img_path):
        return ('human',predict_breed(img_path))
    
    return (None, None)

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__
#
# Output was better than expected. We did get any misclassificaion among these tests. However, this is likely due to our small sample size, not the accuracy of the algorithm.
#
# Points for improvement:
#
# * Arguement the training set so that the algorithm can adapt better to novel images
# * Train the CNN *after* connecting the feature layer and the additional layers
# *

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
from sklearn.datasets import load_files       
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

demo_files = load_files('demo')['filenames']

for img in demo_files:
    print('-'*80)
    print('Looking into',img)
    (subject,breed) = img_to_facts(img)
    if subject=='dog':
        print('This looks like a dog of the %s breed'%breed)
    elif subject=='human':
        print('This is a human who has a look resembling that of %s'%breed)
    else:
        print('I did not see a human nor a dog here')
    plt.imshow(mpimg.imread(img))
    plt.show()
# Out:
# --------------------------------------------------------------------------------
# Looking into demo/imgs/yorkshire_terrier.jpg
# This looks like a dog of the Yorkshire_terrier breed
# --------------------------------------------------------------------------------
# Looking into demo/imgs/funny-dog-names.jpg
# This looks like a dog of the Chinese_shar-pei breed
# --------------------------------------------------------------------------------
# Looking into demo/imgs/dribbble_mathieubeaulieu_firstwave-objects_03.png
# I did not see a human nor a dog here
# --------------------------------------------------------------------------------
# Looking into demo/imgs/learn-more-health-nucleus.jpg
# This is a human who has a look resembling that of Welsh_springer_spaniel
# --------------------------------------------------------------------------------
# Looking into demo/imgs/Dog-Old_English_Sheepdog-A_Old_English_Sheepdog,_sitting_beautifully,_waiting_for_a_command.jpg
# This looks like a dog of the Old_english_sheepdog breed
# --------------------------------------------------------------------------------
# Looking into demo/imgs/teenager-183.jpg
# This is a human who has a look resembling that of Old_english_sheepdog
